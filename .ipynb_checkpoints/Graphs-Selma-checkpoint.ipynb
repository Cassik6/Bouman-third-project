# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("immo_data_set.csv")

# %%
df
# Out:
#        Unnamed: 0  hyperlink  postcode  Province            Region  house_is  \
# 0               0    5750433      1180  Brussels  Brussels Capital         1
# 1               1    6123397      1190  Brussels  Brussels Capital         1
# 2               2    6532849      1150  Brussels  Brussels Capital         1
# 3               3    6763920      1080  Brussels  Brussels Capital         0
# 4               4    6768678      1180  Brussels  Brussels Capital         1
# ...           ...        ...       ...       ...               ...       ...
# 23802       23802    8957939      5300     Namur    Walloon Region         0
# 23803       23803    8957983      5537     Namur    Walloon Region         1
# 23804       23804    8958286      5000     Namur    Walloon Region         1
# 23805       23805    8958297      5002     Namur    Walloon Region         1
# 23806       23806    8958308      5020     Namur    Walloon Region         1
#
#       property_subtype      price  rooms_number  area  ... open_fire terrace  \
# 0                VILLA  2750000.0             7     4  ...     False    True
# 1                HOUSE  1325000.0             6     4  ...       NaN     NaN
# 2                VILLA  3800000.0             7    -1  ...     False    True
# 3            PENTHOUSE   299000.0             2   135  ...     False    True
# 4                VILLA  2350000.0             5     5  ...     False    True
# ...                ...        ...           ...   ...  ...       ...     ...
# 23802        APARTMENT   279000.0             2   143  ...     False    True
# 23803            HOUSE   278500.0             3     1  ...     False   False
# 23804            HOUSE   210000.0             5   187  ...     False    True
# 23805  APARTMENT_BLOCK   300000.0             4     1  ...     False    True
# 23806            HOUSE   220000.0             3     1  ...     False   False
#
#       terrace_area garden  garden_area land_surface  land_plot_surface  \
# 0              0.0  False          0.0       2600.0             2600.0
# 1              NaN    NaN          NaN          NaN              800.0
# 2             80.0  False          0.0       1367.0             1367.0
# 3             11.0  False          0.0          0.0              135.0
# 4              0.0  False          0.0       1530.0             1530.0
# ...            ...    ...          ...          ...                ...
# 23802         20.0   True         50.0          NaN                NaN
# 23803          0.0   True        700.0          NaN              840.0
# 23804          0.0  False          NaN          NaN                NaN
# 23805          0.0  False          NaN          NaN                NaN
# 23806          0.0   True        750.0          NaN              910.0
#
#        facades_number  swimming_pool_has  building_state
# 0                 0.0              False          AS_NEW
# 1                 3.0                NaN             NaN
# 2                 0.0              False          AS_NEW
# 3                 0.0              False          AS_NEW
# 4                 0.0              False          AS_NEW
# ...               ...                ...             ...
# 23802             2.0              False             NaN
# 23803             3.0              False             NaN
# 23804             2.0              False             NaN
# 23805             3.0              False             NaN
# 23806             4.0              False             NaN
#
# [23807 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23807 entries, 0 to 23806
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         23807 non-null  int64
#  1   hyperlink          23807 non-null  int64
#  2   postcode           23807 non-null  int64
#  3   Province           23807 non-null  object
#  4   Region             23807 non-null  object
#  5   house_is           23807 non-null  int64
#  6   property_subtype   23807 non-null  object
#  7   price              23807 non-null  float64
#  8   rooms_number       23807 non-null  int64
#  9   area               23807 non-null  int64
#  10  kitchen_has        23084 non-null  object
#  11  furnished          22752 non-null  object
#  12  open_fire          22942 non-null  object
#  13  terrace            22137 non-null  object
#  14  terrace_area       22137 non-null  float64
#  15  garden             22383 non-null  object
#  16  garden_area        17816 non-null  float64
#  17  land_surface       16848 non-null  float64
#  18  land_plot_surface  20810 non-null  float64
#  19  facades_number     21933 non-null  float64
#  20  swimming_pool_has  22910 non-null  object
#  21  building_state     13367 non-null  object
# dtypes: float64(6), int64(6), object(10)
# memory usage: 4.0+ MB

# %%
#the 5 most expensive properties by average prices for each postcode
df_gb_post_mean = df.groupby(by = "postcode").mean().sort_values(by='price',ascending=False)[:5]
df_gb_post_mean.plot(y= "price" , kind = 'bar')
plt.title ("5 most expensive postcodes")
plt.show()

# %%
#the 5 least expensive properties by average prices for each postcode
df_gb_post_mean = df.groupby(by = "postcode").mean().sort_values(by='price',ascending=True)[:5]
df_gb_post_mean.plot(y= "price" , kind = 'bar')
plt.title ("5 least expensive postcodes")
plt.show()

# %%
# to find out the prices by provinces, we used groupby function
df_gb_province_mean = df.groupby(by = "Province").mean().sort_values(by='price',ascending=False)
df_gb_province_mean
# Out:
#                  Unnamed: 0     hyperlink     postcode  house_is  \
# Province
# Brussels             1727.0  8.801288e+06  1096.563531  0.306512
# Walloon Brabant     17298.5  8.804479e+06  1388.951613  0.715323
# Flemish Brabant      7178.0  8.797042e+06  2351.579391  0.608899
# West Flanders       10459.0  8.737860e+06  8482.899706  0.416083
# Antwerp              4782.5  8.827025e+06  2417.560241  0.487575
# East Flanders       14312.5  8.795543e+06  9363.355793  0.560671
# Limburg             16315.5  8.800337e+06  3709.831956  0.549587
# Namur               23420.0  8.803779e+06  5305.791721  0.778784
# Hainaut             18643.5  8.757049e+06  7386.708966  0.808966
# Liège               20403.5  8.779910e+06  4373.947343  0.740097
# Luxembourg          22236.0  8.780019e+06  6430.829467  0.781191
#
#                          price  rooms_number        area  terrace_area  \
# Province
# Brussels         684317.211867      3.019103   82.032996     14.042478
# Walloon Brabant  594276.920968      3.900806  100.577419     20.949550
# Flemish Brabant  515908.447775      3.133489   95.508197     12.304743
# West Flanders    459543.627061      2.641518   82.292297      5.553071
# Antwerp          447410.164910      2.876883   96.987575      9.695291
# East Flanders    370406.875610      2.910061   93.464329      8.471955
# Limburg          318697.630854      2.849862   98.114325      9.165939
# Namur            290099.285899      3.428202   77.393273     10.592958
# Hainaut          286406.572414      3.399310   86.343448     11.480620
# Liège            281998.198068      3.484058   84.281643     13.910323
# Luxembourg       257199.742320      3.380564   81.613166      8.690278
#
#                  garden_area  land_surface  land_plot_surface  facades_number
# Province
# Brussels           76.389993    152.648774         264.638341        0.355475
# Walloon Brabant   652.283186   2140.611399        2320.726343        0.716569
# Flemish Brabant   205.241946   1067.139946        1239.507945        0.845148
# West Flanders      97.340759    730.355146         815.273237        0.496315
# Antwerp           239.160197    665.778912         709.251160        1.002123
# East Flanders      87.329996    456.664750         600.939845        0.634789
# Limburg           175.914634    979.019444        1249.005464        1.345369
# Namur             716.495798   1072.741818        1174.048023        0.938525
# Hainaut           378.824047    985.397516         906.074604        0.887673
# Liège             266.055789    811.555627         734.766002        0.726226
# Luxembourg        264.911975   1021.928571        1010.808981        0.771373

# %%
df_gb_province_mean.plot(y= "price" , kind = 'bar')
plt.title("The Average Price by Province")
plt.show()

# %%
#to see the prices according to property type we grouped the data frame by privinces and property types
df.groupby(["Province", "property_subtype"]).mean().sort_values(by='price',ascending=False)
# Out:
#                                     Unnamed: 0     hyperlink     postcode  \
# Province        property_subtype
# Hainaut         OTHER_PROPERTY    19348.000000  8.957146e+06  7760.000000
#                 CASTLE            17948.000000  7.768432e+06  7711.000000
# Liège           CASTLE            19525.500000  8.307536e+06  4885.000000
# Flemish Brabant CASTLE             7107.333333  8.861274e+06  2671.333333
# Antwerp         CASTLE             5811.000000  8.952363e+06  2800.000000
# ...                                        ...           ...          ...
#                 CHALET             5153.666667  8.916489e+06  2230.000000
# Luxembourg      BUNGALOW          22914.000000  8.951125e+06  6690.000000
#                 FLAT_STUDIO       22931.500000  8.951832e+06  6650.000000
# Antwerp         BUNGALOW           3806.000000  8.688288e+06  2490.000000
# Walloon Brabant FLAT_STUDIO       16873.000000  8.712422e+06  1400.000000
#
#                                   house_is         price  rooms_number  \
# Province        property_subtype
# Hainaut         OTHER_PROPERTY         1.0  5.000000e+06     90.000000
#                 CASTLE                 1.0  3.500000e+06      8.000000
# Liège           CASTLE                 1.0  3.000000e+06     18.500000
# Flemish Brabant CASTLE                 1.0  2.648333e+06     13.333333
# Antwerp         CASTLE                 1.0  2.500000e+06     10.000000
# ...                                    ...           ...           ...
#                 CHALET                 1.0  6.500000e+04      1.666667
# Luxembourg      BUNGALOW               1.0  6.245000e+04      2.500000
#                 FLAT_STUDIO            0.0  6.150000e+04      0.000000
# Antwerp         BUNGALOW               1.0  6.000000e+04      2.000000
# Walloon Brabant FLAT_STUDIO            0.0  5.500000e+04      0.000000
#
#                                         area  terrace_area  garden_area  \
# Province        property_subtype
# Hainaut         OTHER_PROPERTY     -1.000000      0.000000          0.0
#                 CASTLE             -1.000000      0.000000          NaN
# Liège           CASTLE             -1.000000      1.500000          0.0
# Flemish Brabant CASTLE              0.666667     13.333333          0.0
# Antwerp         CASTLE            667.000000      0.000000      40731.0
# ...                                      ...           ...          ...
#                 CHALET             35.333333      0.000000          NaN
# Luxembourg      BUNGALOW           36.500000      7.500000        200.0
#                 FLAT_STUDIO        11.500000      0.000000          0.0
# Antwerp         BUNGALOW           95.000000      0.000000          NaN
# Walloon Brabant FLAT_STUDIO        22.000000      0.000000          0.0
#
#                                   land_surface  land_plot_surface  \
# Province        property_subtype
# Hainaut         OTHER_PROPERTY        0.000000        3600.000000
#                 CASTLE                     NaN       18000.000000
# Liège           CASTLE            40000.000000       27500.000000
# Flemish Brabant CASTLE            10696.333333       10696.333333
# Antwerp         CASTLE            41412.000000       41412.000000
# ...                                        ...                ...
#                 CHALET                     NaN         966.333333
# Luxembourg      BUNGALOW                   NaN         250.000000
#                 FLAT_STUDIO           0.000000           0.000000
# Antwerp         BUNGALOW                   NaN        1250.000000
# Walloon Brabant FLAT_STUDIO           0.000000          22.000000
#
#                                   facades_number
# Province        property_subtype
# Hainaut         OTHER_PROPERTY               0.0
#                 CASTLE                       4.0
# Liège           CASTLE                       2.0
# Flemish Brabant CASTLE                       0.0
# Antwerp         CASTLE                       0.0
# ...                                          ...
#                 CHALET                       4.0
# Luxembourg      BUNGALOW                     4.0
#                 FLAT_STUDIO                  2.0
# Antwerp         BUNGALOW                     4.0
# Walloon Brabant FLAT_STUDIO                  0.0
#
# [222 rows x 12 columns]

# %%
property_t_list = df.groupby("property_subtype").count().index.to_list()

# %%
# this function is generating graphs according to provinces
def type_to_bar (type_prop):
    df_type = df.loc[df["property_subtype"] == type_prop].groupby("Province").mean().sort_values(by='price',ascending=False)
    df_type.plot(y= "price" , kind = 'bar')
    plt.title(type_prop)

# use the function for each property types
for n in property_t_list:
    type_to_bar(n)
# Out:
# /Users/mselmaesen/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
type_to_bar("APARTMENT")

# %%
#This graph shows the count distribution of selling properties for each provinces.
df_province_count = df.groupby("Province").count()
plot = df_province_count.plot.pie(y = "hyperlink", figsize=(5, 5), subplots=False, autopct='%1.1f%%',
                                  legend = False, fontsize=10)
plt.title("The Distribution of Sellig Properties by Provinces")
# Out:
# Text(0.5, 1.0, 'The Distribution of Sellig Properties by Provinces')

# %%
df_province_count = df.groupby("Region").count()
plot = df_province_count.plot.pie(y = "hyperlink", figsize=(5, 5), subplots=False, autopct='%1.1f%%',
                                  legend = False, fontsize=10)
plt.title("The Distribution of Sellig Properties by Region")
# Out:
# Text(0.5, 1.0, 'The Distribution of Sellig Properties by Region')

# %%
# the avrage price of houses and apartments by province
sns.set_style('whitegrid')
df_a_h = df[df["property_subtype"].isin(["APARTMENT", "HOUSE"])]
plt.figure(figsize=(12,8))
sns.barplot(x='Province', y= "price",hue='property_subtype',data=df_a_h)
plt.xticks(rotation=90)
plt.title ("Average price of selling houses and apartments by province")
# Out:
# Text(0.5, 1.0, 'Average price of selling houses and apartments by province')

# %%
#total number of selling houses and apartments by province
plt.figure(figsize=(12,8))
sns.countplot(x='Province',hue='property_subtype',data=df_a_h)
plt.xticks(rotation=90)
plt.title ("Number of selling houses and apartments by province")
# Out:
# Text(0.5, 1.0, 'Number of selling houses and apartments by province')

# %%
# the avrage price of houses and apartments by region

plt.figure(figsize=(12,8))
sns.barplot(x='Region', y= "price",hue='property_subtype',data=df_a_h)
plt.xticks(rotation=90)
plt.title ("Average price of selling houses and apartments by region")
# Out:
# Text(0.5, 1.0, 'Average price of selling houses and apartments by region')

# %%
#total number of selling houses and apartments by region

plt.figure(figsize=(12,8))
sns.countplot(x='Region',hue='property_subtype',data=df_a_h)
plt.xticks(rotation=90)
plt.title ("Number of selling houses and apartments by region")
# Out:
# Text(0.5, 1.0, 'Number of selling houses and apartments by region')
